# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
api_key=os.getenv("GEMINI_API_KEY")

# %%
import requests

# %%
headers={"content-Type":"application/json"}

# %%
payload={
  "contents": [
    {
      "parts": [
        { "text": "tell me a fun fact" }
      ]
    }
  ]
}

# %%
from requests import api


response=requests.post(
    f"https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?key={api_key}",
    headers=headers,
    json=payload
)
response.json()["candidates"][0]["content"]["parts"][0]["text"]
# Out:
# 'Here\'s one for you:\n\n**Bananas are technically berries, but strawberries, raspberries, and blackberries are not!**\n\nBotanically speaking, a berry is a fleshy fruit produced from a single ovary. Bananas fit this description, while strawberries, for example, are "aggregate fruits" that develop from multiple ovaries of a single flower. Mind-blowing, right?'
